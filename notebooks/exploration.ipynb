# %%
import pandas as pd

df = pd.read_csv(
    "../data/raw/events_2019_10.csv",
    nrows=1_000_000
)

# %%
display(df.columns)

display(df['event_type'].value_counts())

display(df['event_time'].min(), df['event_time'].max())
# Out:
# Index(['event_time', 'event_type', 'product_id', 'category_id',
#        'category_code', 'brand', 'price', 'user_id', 'user_session'],
#       dtype='object')
# event_type
# view        968513
# purchase     16848
# cart         14639
# Name: count, dtype: int64
# '2019-10-01 00:00:00 UTC'
# '2019-10-01 16:56:07 UTC'

# %% [markdown]
# ## Initial Findings
#
# - The dataset contains user-level event data for an e-commerce platform.
# - Events follow a clear funnel: view → cart → purchase.
# - The vast majority of events are product views, which is expected.
# - Purchase events represent a small fraction of total events.
# - The analysis is based on a sample of the data for initial exploration.
